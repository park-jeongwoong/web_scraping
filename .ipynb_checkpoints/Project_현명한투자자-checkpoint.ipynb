# %%
# [1] 코스닥 지수 구성종목 분석 페이지를 시가총액 순으로 긁어오자.

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

def create_analysis_link(link):
    new = 'https://finance.naver.com' + link
    return 'https://finance.naver.com' + link[:6] + 'coinfo' + link[10:]


links = [] # 최종적인 링크들을 담을 테이블
# 시가총액 1~200위 페이지
for page in range(1,5):
    html = urlopen('https://finance.naver.com/sise/sise_market_sum.nhn?sosok=1&page='+str(page))
    bs = BeautifulSoup(html, 'html.parser')
    rankings = bs.findAll('a',{'href' : re.compile('^(/item/main.)')})

    # 각 종목별 페이지로 연결
    for ranking in rankings:
            if 'href' in ranking.attrs:
                midLink = str(create_analysis_link(ranking.attrs['href']))
                
                # 종목별 페이지 속의 '재무분석' 페이지로 연결
                html = urlopen("{}".format(midLink))
                bs = BeautifulSoup(html,'html.parser')
                link = bs.find('div', {'class' : 'section inner_sub'}).find('iframe')
                
                if 'src' in link.attrs:
                    financialLink = link.attrs['src']
                    links.append(financialLink)
                    
print(links[32])
# Out:
# https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=214150

# %%
# 결과만 정리.

links=['https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=091990', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=247540', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=066970', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=263750', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=293490', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=112040', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=068760', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=278280', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=028300', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=035760', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=253450', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=058470', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=096530', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=086520', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=196170', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=108320', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=035900', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=048260', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=005290', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=041510', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=240810', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=357780', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=237690', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=025900', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=067160', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=222800', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=299900', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=034230', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=078600', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=064760', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=078340', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=348370', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=214150', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=056190', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=039030', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=032500', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=145020', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=195940', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=098460', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=215600', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=376300', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=298380', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=053800', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=122870', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=036930', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=215200', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=030190', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=003380', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=141080', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=137400', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=007390', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=144510', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=048410', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=036540', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=095700', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=213420', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=166090', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=085660', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=200130', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=084370', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=272290', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=214370', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=215000', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=121800', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=214450', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=064550', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=067630', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=060250', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=086450', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=289220', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=022100', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=068240', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=256840', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=041140', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=383310', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=218410', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=067310', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=140860', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=222080', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=069080', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=194480', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=206650', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=086900', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=290650', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=151910', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=182400', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=084850', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=039200', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=090460', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=000250', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=046890', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=063080', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=189300', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=064260', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=025980', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=084990', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=950180', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=041190', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=235980', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=131290', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=101730', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=085370', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=178320', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=048530', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=950220', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=225570', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=294090', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=319660', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=323990', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=100090', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=074600', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=033290', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=089980', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=230360', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=033640', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=121600', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=092040', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=287410', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=199800', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=220630', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=091120', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=101490', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=348210', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=217270', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=091700', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=950130', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=006730', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=131970', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=043150', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=049070', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=047820', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=036830', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=035600', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=206560', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=041960', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=205470', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=106240', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=082270', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=183300', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=039840', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=086390', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=291230', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=038500', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=095660', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=089970', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=294570', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=095610', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=290510', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=067000', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=032190', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=382840', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=038540', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=330860', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=061970', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=030520', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=267980', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=060150', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=088800', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=268600', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=053030', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=110790', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=950160', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=293780', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=042000', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=035080', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=036810', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=003800', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=230240', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=243070', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=060720', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=299030', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=298540', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=016790', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=095340', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=104480', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=317330', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=143240', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=027360', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=063170', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=013120', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=058820', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=048550', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=080160', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=054210', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=131390', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=151860', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=078130', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=243840', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=298870', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=042420', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=307750', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=104830', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=003100', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=232140', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=051500', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=035890', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=032300', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=077360', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=094480', 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=100790']

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

import time

data = []

for one in links:
    # headless 설정
    options = webdriver.ChromeOptions()
    options.add_argument('headless')

    # 브라우저 생성
    browser = webdriver.Chrome(chrome_options=options)
    browser.get('{}'.format(one))
    
    try: # ETF를 걸러줄 장치
    
        # 종목 이름 구하기
        elementXpath = '//*[@id="pArea"]/div[1]/div/table/tbody/tr[1]/td/dl/dt[1]/span'
        title = browser.find_element(by=By.XPATH, value = elementXpath).text

        # 시가총액 구하기
        elementXpath = '//*[@summary="기업의 기본적인 시세정보(주가/전일대비/수익률,52주최고/최저,액면가,거래량/거래대금,시가총액,유동주식비율,외국인지분율,52주베타,수익률(1M/3M/6M/1Y))를 제공합니다."]/tbody/tr[5]/td'
        market_cap = float(browser.find_element(by=By.XPATH, value = elementXpath).text[:-2].replace(",",""))

        # 포괄손익계산서 이동하기
        browser.find_element_by_link_text("재무분석").click()
        browser.find_element_by_link_text("포괄손익계산서").click()

        time.sleep(1)
        # 영업이익 비교하기_ 조건 불합시 continue
        try: 
            elementXpath = '//table[@summary="IFRS연결 연간 재무 정보를 제공합니다."][2]/tbody/tr[58]/td[5]'
            O_profit2020 = browser.find_element(by=By.XPATH, value = elementXpath).text

            elementXpath = '//table[@summary="IFRS연결 연간 재무 정보를 제공합니다."][2]/tbody/tr[58]/td[4]'
            O_profit2019 = browser.find_element(by=By.XPATH, value = elementXpath).text

            if O_profit2020 <= O_profit2019:
                browser.quit()
                continue

        except: # 영업이익이 안뜨는 상황.
            browser.quit()
            continue

        # 재무상태표 이동하기
        browser.find_element_by_link_text("재무상태표").click()
        time.sleep(1)

        # 순운전자본 구하기
        elementXpath = '//table[@summary="IFRS연결 연간 재무 정보를 제공합니다."][2]/tbody/tr[2]/td[5]'
        current_asset = float(browser.find_element(by=By.XPATH, value = elementXpath).text.replace(",",""))

        elementXpath = '//table[@summary="IFRS연결 연간 재무 정보를 제공합니다."][2]/tbody/tr[128]/td[5]'
        current_liabilities = float(browser.find_element(by=By.XPATH, value = elementXpath).text.replace(",",""))

        elementXpath = '//table[@summary="IFRS연결 연간 재무 정보를 제공합니다."][2]/tbody/tr[47]/td[5]'
        cashable_asset = float(browser.find_element(by=By.XPATH, value = elementXpath).text.replace(",",""))

        net_working_capital = current_asset - current_liabilities + cashable_asset

        # 순운전자본과 시가총액 비교
        if net_working_capital < market_cap:
            browser.quit()
            continue

        # 조건으로부터 살아남았다면, 수익률 계산(추가 작성 예정)

        # 조건으로부터 살아남았다면, 리스트 테이블에 추가
        data.append([(title, current_asset, current_liabilities, net_working_capital, market_cap, round(market_cap/net_working_capital*100,2))])
                    
    except: # ETF는 거른다.
        continue

# 데이터 저장
import csv

csvFile = open('COSDAC200_Finance.csv', 'wt+', newline = '')
writer = csv.writer(csvFile)

writer.writerow(('기업 이름', '유동자산(억)', '유동부채(억)', '순운전자본(억)', '시가총액(억)', '시총/순운전자본'))

try:
    for one in data:
        writer.writerow(one)
        
finally:
    csvFile.close()
# Out:
# C:\Users\dck\AppData\Local\Temp/ipykernel_15416/1645717083.py:14: DeprecationWarning: use options instead of chrome_options
#   browser = webdriver.Chrome(chrome_options=options)
# C:\Users\dck\AppData\Local\Temp/ipykernel_15416/1645717083.py:28: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
#   browser.find_element_by_link_text("재무분석").click()
# C:\Users\dck\AppData\Local\Temp/ipykernel_15416/1645717083.py:29: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
#   browser.find_element_by_link_text("포괄손익계산서").click()
# C:\Users\dck\AppData\Local\Temp/ipykernel_15416/1645717083.py:49: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
#   browser.find_element_by_link_text("재무상태표").click()

# %%
"""
시간이 없어 아직 테스트도 못해봤지만
데이터가 잘 정리되어 저장되었다고 가정하자.

이번에는 거르는 데이터가 많아 훨씬 빠르게 동작할 것이다.


# 개선점(1)
수익률을 내가 일일이 찾아볼 수는 없는 일이다.
내일 다시 작업을 한다면 수익률까지 추출할 수 있는 방법을 찾아내자. 어렵지 않을 것이다.

# 개선점(2)
페이지가 아직 4페이지 까지로, 200위까지밖에 반영하지 못한다.
한 10페이지까지 해버리자. 동작만 된다면 못할게 뭔가. 
메모리에 누적되는 방식도 아니므로 20페이지도 무리없다.
대신 이정도 사이즈라면 내가 수익률을 찾아보는 것은 당연히 무리이므로 반드시 수익률까지 시간 걸리지 않게 구해야한다.

# 개선점(3)
이것은 어디까지나 '테스트'용이다.
1년동안의 수익률을 살펴보는 정도.
결과가 좋다면 앞으로 1년의 내용을 작성해보자.
실제로 투자로 이어질 수 있을 정도까지 간다면 좋겠다.
"""
